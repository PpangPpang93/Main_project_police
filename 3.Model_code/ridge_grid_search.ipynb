# %%
import pandas as pd
import numpy as np
#import matplotlib.pyplot as plt
#import seaborn as sns

# %%
df = pd.read_csv('total_data1.csv')

# %% [markdown]
# ### xdata로 상관계수가 높은 column을 넣어서 Ridge
# - elasticnet으로 상관계수가 높은 feature를 넣어 모델생성

# %%
from sklearn.metrics import mean_squared_error

# %%
# 필요 패키지 로드
#from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error

# %%
# y값인 q1-q5가 결측인 2020년 데이터 제거
a = df[0:-82]
a
# Out:
#       jur_stn       year  child  house  report_sx_total  vio_cnt  mur_rob_cnt  \
# 0     서울중부경찰서  2017(상반기)   39.0   97.0          22574.0   1324.0          0.0
# 1     서울종로경찰서  2017(상반기)   46.0   98.0          19674.0   1102.0          0.0
# 2    서울남대문경찰서  2017(상반기)   39.0   97.0          14499.0    949.0          0.0
# 3    서울서대문경찰서  2017(상반기)   39.0   98.0          38769.0   1924.0          0.0
# 4     서울혜화경찰서  2017(상반기)   46.0   98.0          18857.0   1127.0          0.0
# ..        ...        ...    ...    ...              ...      ...          ...
# 241   창원서부경찰서  2019(하반기)   44.0   87.0          22771.0   1460.0          2.0
# 242   마산중부경찰서  2019(하반기)   37.0   88.0          21264.0   1265.0          5.0
# 243   마산동부경찰서  2019(하반기)   44.0   86.0          26014.0   1715.0          8.0
# 244     진주경찰서  2019(하반기)   64.0   92.0          38557.0   2552.0          0.0
# 245     진해경찰서  2019(하반기)   37.0   89.0          20320.0   1444.0          0.0
#
#      car_cnt   popu_합계   for_합계  ...     vic_w  vic_unknown  case_car_man  \
# 0     1412.0   63948.0   5132.5  ...  0.241636     0.022305      0.274074
# 1      867.0   78638.5   5489.5  ...  0.262745     0.039216      0.282353
# 2      736.0   63948.0   5132.5  ...  0.203922     0.043137      0.247059
# 3     1788.0  321345.0  13152.0  ...  0.243697     0.044118      0.266807
# 4      899.0   78638.5   5489.5  ...  0.217054     0.046512      0.262548
# ..       ...       ...      ...  ...       ...          ...           ...
# 241   1964.0  256001.0   5100.0  ...  0.286982     0.047337      0.218935
# 242   1584.0  177579.0   3145.0  ...  0.280000     0.092308      0.258462
# 243   1910.0  192446.0   2871.0  ...  0.345679     0.032922      0.345679
# 244   3570.0  354166.0   7152.0  ...  0.357320     0.057072      0.357320
# 245   1692.0  190885.0   4917.0  ...  0.287982     0.049887      0.201814
#
#      case_car_car  case_car_only    q1    q2    q3    q4    q5
# 0        0.703704       0.022222  75.2  76.5  69.9  65.9  72.6
# 1        0.682353       0.035294  81.6  82.4  69.1  62.7  72.2
# 2        0.713725       0.039216  77.3  79.3  68.8  61.0  71.7
# 3        0.691176       0.042017  78.0  80.0  67.0  66.3  71.4
# 4        0.694981       0.042471  78.6  80.6  70.7  65.2  75.4
# ..            ...            ...   ...   ...   ...   ...   ...
# 241      0.733728       0.047337  79.1  79.5  68.5  71.2  76.0
# 242      0.649231       0.092308  80.8  80.0  70.8  73.2  76.5
# 243      0.621399       0.032922  75.0  76.5  69.4  68.9  73.1
# 244      0.588089       0.054591  78.7  79.6  70.3  74.6  75.6
# 245      0.752834       0.045351  76.6  79.2  67.0  70.9  73.5
#
# [246 rows x 67 columns]

# %%
# 경찰서와 연도 데이터 제거
a.drop(columns = ['jur_stn', 'year'], inplace = True)
# Out:
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
a_ = a.drop(columns = ['q1', 'q2', 'q3', 'q4', 'q5'])

# %%
a_
# Out:
#      child  house  report_sx_total  vio_cnt  mur_rob_cnt  car_cnt   popu_합계  \
# 0     39.0   97.0          22574.0   1324.0          0.0   1412.0   63948.0
# 1     46.0   98.0          19674.0   1102.0          0.0    867.0   78638.5
# 2     39.0   97.0          14499.0    949.0          0.0    736.0   63948.0
# 3     39.0   98.0          38769.0   1924.0          0.0   1788.0  321345.0
# 4     46.0   98.0          18857.0   1127.0          0.0    899.0   78638.5
# ..     ...    ...              ...      ...          ...      ...       ...
# 241   44.0   87.0          22771.0   1460.0          2.0   1964.0  256001.0
# 242   37.0   88.0          21264.0   1265.0          5.0   1584.0  177579.0
# 243   44.0   86.0          26014.0   1715.0          8.0   1910.0  192446.0
# 244   64.0   92.0          38557.0   2552.0          0.0   3570.0  354166.0
# 245   37.0   89.0          20320.0   1444.0          0.0   1692.0  190885.0
#
#       for_합계  popu_u20  popu_o60  ...    vic_20   vic_340  vic_5670  vic_80ov  \
# 0     5132.5    8387.0   14108.0  ...  0.129278  0.349810  0.471483  0.019011
# 1     5489.5   11965.5   16858.0  ...  0.129555  0.404858  0.429150  0.024291
# 2     5132.5    8387.0   14108.0  ...  0.111111  0.399177  0.465021  0.012346
# 3    13152.0   49895.0   65887.0  ...  0.167033  0.342857  0.430769  0.021978
# 4     5489.5   11965.5   16858.0  ...  0.141700  0.340081  0.485830  0.020243
# ..       ...       ...       ...  ...       ...       ...       ...       ...
# 241   5100.0   44789.0   49023.0  ...  0.111801  0.378882  0.456522  0.024845
# 242   3145.0   28095.0   50991.0  ...  0.091525  0.355932  0.498305  0.033898
# 243   2871.0   32856.0   47491.0  ...  0.140426  0.340426  0.434043  0.029787
# 244   7152.0   66710.0   79729.0  ...  0.134211  0.310526  0.465789  0.036842
# 245   4917.0   40507.0   38297.0  ...  0.128878  0.396181  0.393795  0.040573
#
#         vic_m     vic_w  vic_unknown  case_car_man  case_car_car  \
# 0    0.736059  0.241636     0.022305      0.274074      0.703704
# 1    0.698039  0.262745     0.039216      0.282353      0.682353
# 2    0.752941  0.203922     0.043137      0.247059      0.713725
# 3    0.712185  0.243697     0.044118      0.266807      0.691176
# 4    0.736434  0.217054     0.046512      0.262548      0.694981
# ..        ...       ...          ...           ...           ...
# 241  0.665680  0.286982     0.047337      0.218935      0.733728
# 242  0.627692  0.280000     0.092308      0.258462      0.649231
# 243  0.621399  0.345679     0.032922      0.345679      0.621399
# 244  0.585608  0.357320     0.057072      0.357320      0.588089
# 245  0.662132  0.287982     0.049887      0.201814      0.752834
#
#      case_car_only
# 0         0.022222
# 1         0.035294
# 2         0.039216
# 3         0.042017
# 4         0.042471
# ..             ...
# 241       0.047337
# 242       0.092308
# 243       0.032922
# 244       0.054591
# 245       0.045351
#
# [246 rows x 60 columns]

# %%
a_.columns
# Out:
# Index(['child', 'house', 'report_sx_total', 'vio_cnt', 'mur_rob_cnt',
#        'car_cnt', 'popu_합계', 'for_합계', 'popu_u20', 'popu_o60', 'for_u20',
#        'for_2030', 'single_합계', 'single_u20', 'single_2030', 'single_4050',
#        'single_o60', 'single_f_합계', 'single_f_u20', 'single_f_2030',
#        'single_f_4050', 'single_f_o60', 'popu_2050', 'for_o40', '총범죄발생대비검거수',
#        '절도폭력범죄발생대비검거수', '강도살인범죄발생대비검거수', '교통사고범죄발생대비검거수', '기초질서범죄발생대비검거수',
#        '인구수대비검거수', '외국인인구수대비검거수', '인구수대비경찰수', 'before_q1', 'before_q2',
#        'before_q3', 'before_q4', 'before_q5', 'light_r', 'cctv_r', 'adult_r',
#        'bell_r', 'ofn_10', 'ofn_20', 'ofn_340', 'ofn_5670', 'ofn_80ov',
#        'ofn_m', 'ofn_w', 'ofn_unknown', 'vic_10', 'vic_20', 'vic_340',
#        'vic_5670', 'vic_80ov', 'vic_m', 'vic_w', 'vic_unknown', 'case_car_man',
#        'case_car_car', 'case_car_only'],
#       dtype='object')

# %%
a_1 = a_

# %%
a_2 = a_

# %%
a_3 = a_

# %%
a_4 = a_

# %%
a_5 = a_

# %%
# StandardScaling
scaler1 = StandardScaler()
scaler1.fit(a_1) # scaler에 xdata 학습
a_s1 = scaler1.transform(a_1)
a_s1
# Out:
# array([[-1.16204451, -1.00794068, -0.94618196, ...,  0.39434438,
#         -0.11566933, -0.96802532],
#        [-0.81221223, -0.8173539 , -1.12728457, ...,  0.56656445,
#         -0.52850194,  0.00726295],
#        [-1.16204451, -1.00794068, -1.45045906, ..., -0.16763689,
#          0.07810924,  0.29984943],
#        ...,
#        [-0.91216431, -3.10439533, -0.73135679, ...,  1.88389689,
#         -1.70708755, -0.16973381],
#        [ 0.08735649, -1.96087461,  0.05194325, ...,  2.1260591 ,
#         -2.35115781,  1.44696268],
#        [-1.26199659, -2.53263497, -1.0869424 , ..., -1.10883527,
#          0.83430992,  0.7576378 ]])

# %%
# StandardScaling
scaler2 = StandardScaler()
scaler2.fit(a_2) # scaler에 xdata 학습
a_s2 = scaler2.transform(a_2)
a_s2
# Out:
# array([[-1.16204451, -1.00794068, -0.94618196, ...,  0.39434438,
#         -0.11566933, -0.96802532],
#        [-0.81221223, -0.8173539 , -1.12728457, ...,  0.56656445,
#         -0.52850194,  0.00726295],
#        [-1.16204451, -1.00794068, -1.45045906, ..., -0.16763689,
#          0.07810924,  0.29984943],
#        ...,
#        [-0.91216431, -3.10439533, -0.73135679, ...,  1.88389689,
#         -1.70708755, -0.16973381],
#        [ 0.08735649, -1.96087461,  0.05194325, ...,  2.1260591 ,
#         -2.35115781,  1.44696268],
#        [-1.26199659, -2.53263497, -1.0869424 , ..., -1.10883527,
#          0.83430992,  0.7576378 ]])

# %%
# StandardScaling
scaler3 = StandardScaler()
scaler3.fit(a_3) # scaler에 xdata 학습
a_s3 = scaler3.transform(a_3)
a_s3
# Out:
# array([[-1.16204451, -1.00794068, -0.94618196, ...,  0.39434438,
#         -0.11566933, -0.96802532],
#        [-0.81221223, -0.8173539 , -1.12728457, ...,  0.56656445,
#         -0.52850194,  0.00726295],
#        [-1.16204451, -1.00794068, -1.45045906, ..., -0.16763689,
#          0.07810924,  0.29984943],
#        ...,
#        [-0.91216431, -3.10439533, -0.73135679, ...,  1.88389689,
#         -1.70708755, -0.16973381],
#        [ 0.08735649, -1.96087461,  0.05194325, ...,  2.1260591 ,
#         -2.35115781,  1.44696268],
#        [-1.26199659, -2.53263497, -1.0869424 , ..., -1.10883527,
#          0.83430992,  0.7576378 ]])

# %%
# StandardScaling
scaler4 = StandardScaler()
scaler4.fit(a_4) # scaler에 xdata 학습
a_s4 = scaler4.transform(a_4)
a_s4
# Out:
# array([[-1.16204451, -1.00794068, -0.94618196, ...,  0.39434438,
#         -0.11566933, -0.96802532],
#        [-0.81221223, -0.8173539 , -1.12728457, ...,  0.56656445,
#         -0.52850194,  0.00726295],
#        [-1.16204451, -1.00794068, -1.45045906, ..., -0.16763689,
#          0.07810924,  0.29984943],
#        ...,
#        [-0.91216431, -3.10439533, -0.73135679, ...,  1.88389689,
#         -1.70708755, -0.16973381],
#        [ 0.08735649, -1.96087461,  0.05194325, ...,  2.1260591 ,
#         -2.35115781,  1.44696268],
#        [-1.26199659, -2.53263497, -1.0869424 , ..., -1.10883527,
#          0.83430992,  0.7576378 ]])

# %%
# StandardScaling
scaler5 = StandardScaler()
scaler5.fit(a_5) # scaler에 xdata 학습
a_s5 = scaler5.transform(a_5)
a_s5
# Out:
# array([[-1.16204451, -1.00794068, -0.94618196, ...,  0.39434438,
#         -0.11566933, -0.96802532],
#        [-0.81221223, -0.8173539 , -1.12728457, ...,  0.56656445,
#         -0.52850194,  0.00726295],
#        [-1.16204451, -1.00794068, -1.45045906, ..., -0.16763689,
#          0.07810924,  0.29984943],
#        ...,
#        [-0.91216431, -3.10439533, -0.73135679, ...,  1.88389689,
#         -1.70708755, -0.16973381],
#        [ 0.08735649, -1.96087461,  0.05194325, ...,  2.1260591 ,
#         -2.35115781,  1.44696268],
#        [-1.26199659, -2.53263497, -1.0869424 , ..., -1.10883527,
#          0.83430992,  0.7576378 ]])

# %%
# x데이터 설정 2017, 2018 데이터를 학습용, 2019년 데이터를 검증용 데이터셋으로 설정

xtrain1 = a_s1[:-82]
xtest1 = a_s1[-82:]
xtrain2 = a_s2[:-82]
xtest2 = a_s2[-82:]
xtrain3 = a_s3[:-82]
xtest3 = a_s3[-82:]
xtrain4 = a_s4[:-82]
xtest4 = a_s4[-82:]
xtrain5 = a_s5[:-82]
xtest5 = a_s5[-82:]

# %%
# y데이터 설정 2017, 2018 데이터를 학습용, 2019년 데이터를 검증용 데이터셋으로 설정

train = a[:-82]
test = a[-82:]

ytrain1 = train['q1']
ytrain2 = train['q2']
ytrain3 = train['q3']
ytrain4 = train['q4']
ytrain5 = train['q5']

ytest1 = test['q1']
ytest2 = test['q2']
ytest3 = test['q3']
ytest4 = test['q4']
ytest5 = test['q5']

# %%
a_1.columns
# Out:
# Index(['child', 'house', 'report_sx_total', 'vio_cnt', 'mur_rob_cnt',
#        'car_cnt', 'popu_합계', 'for_합계', 'popu_u20', 'popu_o60', 'for_u20',
#        'for_2030', 'single_합계', 'single_u20', 'single_2030', 'single_4050',
#        'single_o60', 'single_f_합계', 'single_f_u20', 'single_f_2030',
#        'single_f_4050', 'single_f_o60', 'popu_2050', 'for_o40', '총범죄발생대비검거수',
#        '절도폭력범죄발생대비검거수', '강도살인범죄발생대비검거수', '교통사고범죄발생대비검거수', '기초질서범죄발생대비검거수',
#        '인구수대비검거수', '외국인인구수대비검거수', '인구수대비경찰수', 'before_q1', 'before_q2',
#        'before_q3', 'before_q4', 'before_q5', 'light_r', 'cctv_r', 'adult_r',
#        'bell_r', 'ofn_10', 'ofn_20', 'ofn_340', 'ofn_5670', 'ofn_80ov',
#        'ofn_m', 'ofn_w', 'ofn_unknown', 'vic_10', 'vic_20', 'vic_340',
#        'vic_5670', 'vic_80ov', 'vic_m', 'vic_w', 'vic_unknown', 'case_car_man',
#        'case_car_car', 'case_car_only'],
#       dtype='object')

# %%
# 그리드 서치 패키지
from sklearn.model_selection import GridSearchCV

# %%
# 최적 성능을 내는 lasso의 alpha값을 얻기 위해 param_grid 생성

param_grid = {'alpha' : np.linspace(0.001, 10.0, 10000)}

#그리드 서치 설정
grid_search = GridSearchCV(Ridge(), param_grid = param_grid, cv = 10, n_jobs = -1, scoring ='r2')
#grid_search = GridSearchCV(Ridge(), param_grid = param_grid, cv = 10, n_jobs = -1, scoring ='neg_mean_absolute_error')

# %% [markdown]
# #### q1 절도폭력

# %%
# 그리드 서치 후 최고 성능의 모델을 ridge1에 저장

grid_search.fit(xtrain1, ytrain1)
ridge1 = grid_search.best_estimator_

# %%
# MAE 출력

y_pred1 = ridge1.predict(xtest1)
mean_absolute_error(ytest1, y_pred1)
# Out:
# 2.280216815807457

# %%
# 결과

print('alpha =', ridge1.alpha)
print(ridge1.coef_) # Ridge 회귀분석으로 나온 weghit값
print('가장 강한 양의 상관관계: ',a_1.columns[ridge1.coef_.argmax()], '\n가장 강한 음의 상관관계: ', a_1.columns[ridge1.coef_.argmin()])
# Out:
# alpha = 10.0
# [ 0.1858718   0.35944705 -0.18654878 -0.88752003  0.12550527 -0.00879849
#   0.23483285 -0.25640454  0.46469126  0.50380436  0.85031836 -0.29439753
#  -0.17669475  0.36080588  0.12274043 -0.78509441 -0.35994638  0.30965558
#   0.10691769  0.51217057 -0.14159903  0.05857899  0.07225416 -0.33213259
#  -0.30612817 -0.28521751 -0.02244433  0.04295547  0.23212191 -0.43095751
#   0.99679932  0.67407008  0.04719795  0.02266245 -0.26957157  0.1635311
#   0.27777131  0.18326995 -0.26235237 -0.253049    0.18470932 -0.32227054
#  -0.11586935  0.20246951  0.00619761 -0.08666845 -0.39903773  0.31214314
#   0.26027898 -0.34774913 -0.043771    0.18120353  0.03499807 -0.3080387
#  -0.20039405  0.26735254 -0.12913279  0.02064122 -0.08359852  0.24854472]
# 가장 강한 양의 상관관계:  외국인인구수대비검거수
# 가장 강한 음의 상관관계:  vio_cnt

# %% [markdown]
# #### q2 강도살인

# %%
# 그리드 서치 후 최고 성능의 모델을 ela2에 저장

grid_search.fit(xtrain2, ytrain2)
ridge2 = grid_search.best_estimator_

# %%
# MAE 출력

y_pred2 = ridge2.predict(xtest2)
mean_absolute_error(ytest2, y_pred2)
# Out:
# 2.17058264040111

# %%
# 결과

print('alpha =', ridge2.alpha)
print(ridge2.coef_) # Ridge 회귀분석으로 나온 weghit값
print('가장 강한 양의 상관관계: ',a_2.columns[ridge2.coef_.argmax()], '\n가장 강한 음의 상관관계: ', a_2.columns[ridge2.coef_.argmin()])
# Out:
# alpha = 4.566000000000001
# [ 0.0860792   0.4554509  -0.42882456 -1.39474717 -0.04082773  0.67245513
#   0.44065367 -0.35757788  0.36512942  1.13101206  1.47174792 -0.50713043
#  -0.21119051  0.64726755  0.26600496 -1.10801628 -0.61302412  0.37013122
#  -0.29569089  0.61392221 -0.10098044  0.05371732  0.21285102 -0.44627423
#  -0.21074038 -0.11088239 -0.02215864  0.05477171  0.20860851 -0.79054475
#   0.7222386   1.1018597  -0.29250057  0.16025184 -0.52723943  0.31317932
#   0.42472581  0.10930088 -0.19559189 -0.25294844  0.02556162 -0.55658869
#  -0.10951789  0.24595558  0.02282998 -0.02243589 -0.49783467  0.394488
#   0.30491444 -0.03552448 -0.15389     0.13197577  0.11347984 -0.57586571
#   0.02578398  0.08091628 -0.29398064  0.16571328 -0.32548941  0.66159982]
# 가장 강한 양의 상관관계:  for_u20
# 가장 강한 음의 상관관계:  vio_cnt

# %% [markdown]
# #### q3 교통안전

# %%
# 그리드 서치 후 최고 성능의 모델을 lasso3에 저장

grid_search.fit(xtrain3, ytrain3)
ridge3 = grid_search.best_estimator_

# %%
ridge3 = Ridge(alpha = 23)
ridge3.fit(xtrain3, ytrain3)
# Out:
# Ridge(alpha=23)

# %%
# MAE 출력

y_pred3 = ridge3.predict(xtest3)
mean_absolute_error(ytest3, y_pred3)
# Out:
# 2.1638808620936607

# %%
# 결과

print('alpha =', ridge3.alpha)
print(ridge3.coef_) # Ridge 회귀분석으로 나온 weghit값
print('가장 강한 양의 상관관계: ',a_3.columns[ridge3.coef_.argmax()], '\n가장 강한 음의 상관관계: ', a_3.columns[ridge3.coef_.argmin()])
# Out:
# alpha = 23
# [ 0.60462781 -0.01836216  0.33480332  0.07597766  0.05094331 -0.01801049
#   0.12955529 -0.03098228 -0.02389251  0.32231312  0.36155864 -0.06357061
#  -0.17338605  0.10758736 -0.13071408 -0.23385295 -0.16651811  0.02234594
#   0.22738254  0.10056028 -0.08911714 -0.08948507  0.10180638 -0.05404081
#   0.32308556 -0.05319068 -0.00210497  0.03723783  0.19267206  0.11423388
#   0.02766457  0.52296002 -0.01345592  0.01568679  0.13478935 -0.21232877
#  -0.05575848  0.2075885  -0.04617672 -0.14361172  0.12973644 -0.55315098
#  -0.43058753  0.13637724  0.26248718  0.09187102 -0.28458975  0.21837938
#   0.20221084  0.26698087 -0.06346565 -0.14705863  0.1048014  -0.05481377
#  -0.00895966  0.02854603 -0.05046488 -0.08276508  0.03386703  0.16616376]
# 가장 강한 양의 상관관계:  child
# 가장 강한 음의 상관관계:  ofn_10

# %% [markdown]
# #### q4 법질서 준수도

# %%
# 그리드 서치 후 최고 성능의 모델을 lasso4에 저장

grid_search.fit(xtrain4, ytrain4)
ridge4 = grid_search.best_estimator_

# %%
# MAE 출력

y_pred4 = ridge4.predict(xtest4)
mean_absolute_error(ytest4, y_pred4)
# Out:
# 2.4505704047971073

# %%
# 결과

print('alpha =', ridge4.alpha)
print(ridge4.coef_) # Ridge 회귀분석으로 나온 weghit값
print('가장 강한 양의 상관관계: ',a_4.columns[ridge4.coef_.argmax()], '\n가장 강한 음의 상관관계: ', a_4.columns[ridge4.coef_.argmin()])
# Out:
# alpha = 10.0
# [ 0.08422014  0.47496439  0.14834264 -0.31512474  0.90924745  0.72152184
#  -0.16558919 -0.19975831 -0.11015924  0.08660646  0.65342416 -0.33030785
#  -0.23131614  0.15442808 -0.02441021 -0.79282277 -0.16042672  0.17084599
#   0.28093741  0.34898235 -0.48400998  0.13322148 -0.25607675 -0.2081495
#   0.36480096 -0.54529326 -0.28543694  0.0490413   0.16311427 -0.4195897
#   0.58055968 -0.99569428 -0.04666948  0.45819622 -0.02352386  0.81593753
#   0.04091217  0.1235867   0.20385689 -0.3854837   0.20093322 -0.4193185
#  -0.48252598  0.45797532  0.03029416  0.08614095 -0.38301169  0.23971484
#   0.48417109  0.48881207 -0.05618829 -0.22196673  0.16491527 -0.3411742
#   0.12608131 -0.01440109 -0.33302747 -0.25247363  0.13361622  0.38994271]
# 가장 강한 양의 상관관계:  mur_rob_cnt
# 가장 강한 음의 상관관계:  인구수대비경찰수

# %% [markdown]
# #### q5 전반적 안전도

# %%
# 그리드 서치 후 최고 성능의 모델을 lasso4에 저장

grid_search.fit(xtrain5, ytrain5)
ridge5 = grid_search.best_estimator_

# %%
ridge5 = Ridge(alpha = 6.25)
ridge5.fit(xtrain5, ytrain5)
# Out:
# Ridge(alpha=6.25)

# %%
# MAE 출력

y_pred5 = ridge5.predict(xtest5)
mean_absolute_error(ytest5, y_pred5)
# Out:
# 1.9753360018544188

# %%
# 결과

print('alpha =', ridge5.alpha)
print(ridge5.coef_) # Ridge 회귀분석으로 나온 weghit값
print('가장 강한 양의 상관관계: ',a_5.columns[ridge5.coef_.argmax()], '\n가장 강한 음의 상관관계: ', a_5.columns[ridge5.coef_.argmin()])
# Out:
# alpha = 6.25
# [ 0.06421938  0.4187727   0.01456397 -0.98143189  0.27599427  0.34433021
#   0.25962214 -0.1884639   0.36799516  0.6268941   0.78630458 -0.33307267
#  -0.33674456  0.32468536 -0.07203347 -0.87313847 -0.42267696  0.30238462
#   0.04100536  0.52735428 -0.07934469 -0.02891441  0.096653   -0.20399747
#   0.23988935 -0.51472116 -0.10890164 -0.01168908  0.09871749 -0.28613236
#   0.67575661  0.2864437  -0.0625666   0.13997026 -0.18723721  0.13303888
#   0.25390993  0.1604691  -0.01088797 -0.19593194  0.06767935 -0.38309175
#  -0.24771206  0.3046604   0.00549987  0.06127319 -0.37182862  0.27782696
#   0.29352346 -0.01387247 -0.08819971 -0.00617579  0.13260857 -0.30891844
#   0.00401649  0.11547854 -0.32287934 -0.00472153 -0.06880729  0.2824365 ]
# 가장 강한 양의 상관관계:  for_u20
# 가장 강한 음의 상관관계:  vio_cnt
